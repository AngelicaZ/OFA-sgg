# %%
# define the parameters

image_path1 = '/data/c/zhuowan/gqa/data/images/2321187.jpg'
pred_sentence1 = 'building <bin_0><bin_0><bin_499><bin_332> is has window <bin_1><bin_0><bin_499><bin_331> .building <bin_1><bin_1><bin_499><bin_330> , with roof <bin_0><bin_1><bin_499><bin_332>airplane <bin_0><bin_3><bin_499><bin_332><bin_499> .man <bin_0><bin_2><bin_499><bin_332>fence <bin_0><bin_332><bin_332><bin_332> itting on sidewalk <bin_0><bin_292><bin_332><bin_332>f .'
gt_sentence1 = ['arm', '<bin_381>', '<bin_125>', '<bin_396>', '<bin_177>', 'is', 'on', 'man', '<bin_333>', '<bin_86>', '<bin_400>', '<bin_312>', '.', 'bag', '<bin_383>', '<bin_166>', '<bin_409>', '<bin_234>', 'is', 'on', 'arm', '<bin_381>', '<bin_125>', '<bin_396>', '<bin_177>', '.', 'coat', '<bin_110>', '<bin_129>', '<bin_181>', '<bin_243>', 'is', 'on', 'woman', '<bin_90>', '<bin_84>', '<bin_194>', '<bin_325>', '.', 'man', '<bin_162>', '<bin_10>', '<bin_336>', '<bin_332>', 'is', 'wearing', 'coat', '<bin_217>', '<bin_61>', '<bin_327>', '<bin_188>', ',', 'wearing', 'jacket', '<bin_209>', '<bin_59>', '<bin_328>', '<bin_200>', '.', 'woman', '<bin_90>', '<bin_84>', '<bin_194>', '<bin_325>', 'is', 'carrying', 'bag', '<bin_93>', '<bin_176>', '<bin_133>', '<bin_246>', ',', 'wearing', 'boot', '<bin_128>', '<bin_276>', '<bin_158>', '<bin_325>', ',', 'wearing', 'boot', '<bin_146>', '<bin_280>', '<bin_163>', '<bin_319>', ',', 'wearing', 'pant', '<bin_129>', '<bin_227>', '<bin_164>', '<bin_275>', '.']


image_path2 = '/data/c/zhuowan/gqa/data/images/2321185.jpg'
pred_sentence2 = 'snow <bin_0><bin_0><bin_499><bin_374> is has track <bin_0><bin_271><bin_499><bin_373> .'
gt_sentence2 = ['horse', '<bin_335>', '<bin_169>', '<bin_406>', '<bin_258>', 'is', 'carrying', 'person', '<bin_349>', '<bin_135>', '<bin_379>', '<bin_193>', '.', 'horse', '<bin_283>', '<bin_167>', '<bin_363>', '<bin_257>', 'is', 'has', 'tail', '<bin_340>', '<bin_183>', '<bin_361>', '<bin_237>', '.', 'person', '<bin_349>', '<bin_135>', '<bin_379>', '<bin_193>', 'is', 'on', 'horse', '<bin_335>', '<bin_169>', '<bin_406>', '<bin_258>', '.', 'tree', '<bin_163>', '<bin_0>', '<bin_208>', '<bin_128>', 'is', 'near', 'beach', '<bin_0>', '<bin_164>', '<bin_498>', '<bin_324>', '.']


image_path3 = '/data/c/zhuowan/gqa/data/images/2321189.jpg'
pred_sentence3 = 'building <bin_0><bin_0><bin_499><bin_332> is has window <bin_0><bin_1><bin_499><bin_332>fence <bin_0><bin_332><bin_499><bin_331> .building <bin_1><bin_0><bin_499><bin_330> , with clock <bin_0><bin_3><bin_499><bin_332><bin_499> .clock <bin_1><bin_1><bin_499><bin_331>el <bin_0><bin_2><bin_499><bin_332>airplane <bin_0><bin_4><bin_499><bin_332><bin_332> .door <bin_0><bin_5><bin_499><bin_332>vase <bin_0><bin_8><bin_499><bin_332>ite <bin_0><bin_7><bin_499><bin_332>.'
gt_sentence3 = ['face', '<bin_201>', '<bin_103>', '<bin_365>', '<bin_258>', 'is', 'on', 'tower', '<bin_71>', '<bin_0>', '<bin_319>', '<bin_253>', '.', 'window', '<bin_300>', '<bin_252>', '<bin_350>', '<bin_329>', 'is', 'in', 'window', '<bin_433>', '<bin_207>', '<bin_497>', '<bin_317>', '.', 'window', '<bin_191>', '<bin_291>', '<bin_232>', '<bin_329>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'tower', '<bin_71>', '<bin_0>', '<bin_319>', '<bin_253>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_313>', '<bin_132>', '<bin_356>', '<bin_200>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_433>', '<bin_207>', '<bin_497>', '<bin_317>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_307>', '<bin_263>', '<bin_344>', '<bin_332>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_0>', '<bin_244>', '<bin_38>', '<bin_330>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_167>', '<bin_289>', '<bin_236>', '<bin_329>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.']


image_path4 = '/data/c/zhuowan/gqa/data/images/2321188.jpg'
pred_sentence4 = 'building <bin_0><bin_0><bin_374><bin_499> is has roof <bin_0><bin_1><bin_374><bin_498> .man <bin_0><bin_50><bin_50><bin_499> , wearing jacket <bin_0><bin_89><bin_50><bin_271> ,tire <bin_0><bin_396><bin_0><bin_499> .tireel <bin_0><bin_375><bin_0><bin_499><bin_499> itting on truck <bin_0><bin_17><bin_374><bin_499>.'
gt_sentence4 = ['car', '<bin_328>', '<bin_44>', '<bin_426>', '<bin_115>', 'is', 'has', 'window', '<bin_350>', '<bin_47>', '<bin_420>', '<bin_68>', '.', 'leaf', '<bin_342>', '<bin_25>', '<bin_392>', '<bin_47>', 'is', 'on', 'tree', '<bin_333>', '<bin_24>', '<bin_411>', '<bin_57>', '.', 'motorcycle', '<bin_52>', '<bin_1>', '<bin_497>', '<bin_327>', 'is', 'has', 'wheel', '<bin_55>', '<bin_137>', '<bin_219>', '<bin_329>', '.']


image_path5 = '/data/c/zhuowan/gqa/data/images/2321187.jpg'
pred_sentence5 = 'building <bin_0><bin_0><bin_499><bin_332> is has window <bin_1><bin_0><bin_499><bin_331> .building <bin_1><bin_1><bin_499><bin_330> , with roof <bin_0><bin_1><bin_499><bin_332>airplane <bin_0><bin_3><bin_499><bin_332><bin_499> .man <bin_0><bin_2><bin_499><bin_332>fence <bin_0><bin_332><bin_332><bin_332> itting on sidewalk <bin_0><bin_292><bin_332><bin_332>f .'
gt_sentence5 = ['arm', '<bin_381>', '<bin_125>', '<bin_396>', '<bin_177>', 'is', 'on', 'man', '<bin_333>', '<bin_86>', '<bin_400>', '<bin_312>', '.', 'bag', '<bin_383>', '<bin_166>', '<bin_409>', '<bin_234>', 'is', 'on', 'arm', '<bin_381>', '<bin_125>', '<bin_396>', '<bin_177>', '.', 'coat', '<bin_110>', '<bin_129>', '<bin_181>', '<bin_243>', 'is', 'on', 'woman', '<bin_90>', '<bin_84>', '<bin_194>', '<bin_325>', '.', 'man', '<bin_162>', '<bin_10>', '<bin_336>', '<bin_332>', 'is', 'wearing', 'coat', '<bin_217>', '<bin_61>', '<bin_327>', '<bin_188>', ',', 'wearing', 'jacket', '<bin_209>', '<bin_59>', '<bin_328>', '<bin_200>', '.', 'woman', '<bin_90>', '<bin_84>', '<bin_194>', '<bin_325>', 'is', 'carrying', 'bag', '<bin_93>', '<bin_176>', '<bin_133>', '<bin_246>', ',', 'wearing', 'boot', '<bin_128>', '<bin_276>', '<bin_158>', '<bin_325>', ',', 'wearing', 'boot', '<bin_146>', '<bin_280>', '<bin_163>', '<bin_319>', ',', 'wearing', 'pant', '<bin_129>', '<bin_227>', '<bin_164>', '<bin_275>', '.']


image_path6 = '/data/c/zhuowan/gqa/data/images/2321185.jpg'
pred_sentence6 = 'snow <bin_0><bin_0><bin_499><bin_374> is has track <bin_0><bin_271><bin_499><bin_373> .'
gt_sentence6 = ['horse', '<bin_335>', '<bin_169>', '<bin_406>', '<bin_258>', 'is', 'carrying', 'person', '<bin_349>', '<bin_135>', '<bin_379>', '<bin_193>', '.', 'horse', '<bin_283>', '<bin_167>', '<bin_363>', '<bin_257>', 'is', 'has', 'tail', '<bin_340>', '<bin_183>', '<bin_361>', '<bin_237>', '.', 'person', '<bin_349>', '<bin_135>', '<bin_379>', '<bin_193>', 'is', 'on', 'horse', '<bin_335>', '<bin_169>', '<bin_406>', '<bin_258>', '.', 'tree', '<bin_163>', '<bin_0>', '<bin_208>', '<bin_128>', 'is', 'near', 'beach', '<bin_0>', '<bin_164>', '<bin_498>', '<bin_324>', '.']


image_path7 = '/data/c/zhuowan/gqa/data/images/2321189.jpg'
pred_sentence7 = 'building <bin_0><bin_0><bin_499><bin_332> is has window <bin_0><bin_1><bin_499><bin_332>fence <bin_0><bin_332><bin_499><bin_331> .building <bin_1><bin_0><bin_499><bin_330> , with clock <bin_0><bin_3><bin_499><bin_332><bin_499> .clock <bin_1><bin_1><bin_499><bin_331>el <bin_0><bin_2><bin_499><bin_332>airplane <bin_0><bin_4><bin_499><bin_332><bin_332> .door <bin_0><bin_5><bin_499><bin_332>vase <bin_0><bin_8><bin_499><bin_332>ite <bin_0><bin_7><bin_499><bin_332>.'
gt_sentence7 = ['face', '<bin_201>', '<bin_103>', '<bin_365>', '<bin_258>', 'is', 'on', 'tower', '<bin_71>', '<bin_0>', '<bin_319>', '<bin_253>', '.', 'window', '<bin_300>', '<bin_252>', '<bin_350>', '<bin_329>', 'is', 'in', 'window', '<bin_433>', '<bin_207>', '<bin_497>', '<bin_317>', '.', 'window', '<bin_191>', '<bin_291>', '<bin_232>', '<bin_329>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'tower', '<bin_71>', '<bin_0>', '<bin_319>', '<bin_253>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_313>', '<bin_132>', '<bin_356>', '<bin_200>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_433>', '<bin_207>', '<bin_497>', '<bin_317>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_307>', '<bin_263>', '<bin_344>', '<bin_332>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_0>', '<bin_244>', '<bin_38>', '<bin_330>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.', 'window', '<bin_167>', '<bin_289>', '<bin_236>', '<bin_329>', 'is', 'on', 'building', '<bin_0>', '<bin_0>', '<bin_498>', '<bin_331>', '.']

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.patches as patches
import cv2

img = cv2.imread(image_path3)

# Create figure and axes
fig, ax = plt.subplots()

ax.imshow(img[:,:,::-1]) # RGB-> BGR

# Create a Rectangle patch (xy, width, height)
rect = patches.Rectangle((201, 103), 365, 258, linewidth=1, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)


plt.show()
